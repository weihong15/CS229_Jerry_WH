# %% [markdown]
# ## 4a
# ### i
# $$\theta^{(i)} = \sum_{j=1}^i \beta_j\phi(x^{(j)})$$
#
# $$\theta^{(0)} = \sum_{j=1}^0 \beta_j\phi(x^{(j)}) = \overrightarrow{0}$$
#
# ### ii
#
# $$h_{\theta^{(i)}}(x^{(i+1)}) = g({\theta^{(i)}}^T \phi(x^{(i+1)}))  = g(\sum_{j=1}^i \beta_j\phi(x^{(j)})^T \phi(x^{(i+1)})) = g(\sum_{j=1}^i \beta_jK(\phi(x^{(j)}),\phi(x^{(i+1)}))) = sign[\sum_{j=1}^i \beta_jK[\phi(x^{(j)}),\phi(x^{(i+1)})]] $$
#
# ### iii
# $$\beta_{(i+1)} = \alpha (y^{(i+1)} - h_{\theta^{(i)}}(x^{(i+1)})) = \alpha (y^{(i+1)} - sign[\sum_{j=1}^i \beta_jK[\phi(x^{(j)}),\phi(x^{(i+1)})]]$$

# %% [markdown]
# ## 4b

# %%
import perceptron

# %%
perceptron.main()

# %% [markdown]
# ## 4d
#
# works a bit: dot kernel
# works wells: rbf
# completely fail: non_psd
#
# For this dataset, we can see that the blue dots are inside while the red dots are outside. The boundary that seperate them is a circle/ellipse.
#
# For the dot kernel, it does not have any quadratic term, so it is unable to draw the boundary of a circle
# For the rbf, it is infinitely many dimension, so as expected, it will work really well.
# For the non psd, it is not a valid kernel. so it does not work at all

# %%
import jovian
jovian.commit()
# Out:
# [jovian] Committed successfully! https://jovian.ai/weihong15/question-4-574e4
# 'https://jovian.ai/weihong15/question-4-574e4'
