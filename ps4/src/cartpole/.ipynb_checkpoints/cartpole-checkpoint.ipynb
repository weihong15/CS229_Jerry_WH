# %% [markdown]
# ## Q3: cartpole RL

# %%
import cartpole

# %%
cartpole.main(True,0)
cartpole.main(True,1)
cartpole.main(True,2)
cartpole.main(True,3)
_ = cartpole.main(True,4)
# Out:
# [INFO] Failure number 60
# [INFO] Failure number 120
# [INFO] Failure number 135
# [INFO] Failure number 60
# [INFO] Failure number 120
# [INFO] Failure number 180
# [INFO] Failure number 240
# [INFO] Failure number 240
# [INFO] Failure number 60
# [INFO] Failure number 120
# [INFO] Failure number 180
# [INFO] Failure number 240
# [INFO] Failure number 300
# [INFO] Failure number 355
# [INFO] Failure number 60
# [INFO] Failure number 120
# [INFO] Failure number 180
# [INFO] Failure number 240
# [INFO] Failure number 247
# [INFO] Failure number 60
# [INFO] Failure number 120
# [INFO] Failure number 180
# [INFO] Failure number 230

# %% [markdown]
# for seed = 0, the failure number it hit was 135. the red line don't appear to be convergent. However, in seed 1 2 and 4, we can see the algorithm converges ~ 50 num of failures.
#
# For seed 3, we can see that learning curve increase faster than the rest.
#
# I feel that this algorithm is not as stable and a lot of randomness is involve.

# %%
import jovian
jovian.commit()
# Out:
# [jovian] Committed successfully! https://jovian.ai/weihong15/cartpole
# 'https://jovian.ai/weihong15/cartpole'
